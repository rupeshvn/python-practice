# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI

# %%
from typing import TypedDict
from dotenv import load_dotenv

import os
load_dotenv(override=True)

def get_groq_llm():
    return ChatOpenAI(
        model= "openai/gpt-oss-120b",
        base_url="https://api.groq.com/openai/v1",
        api_key = os.getenv("GROQ_API_KEY"),
        temperature = 0.7,
        max_tokens = 1000
        #model_kwargs = {"max_toxens": 1000}
    )

llm = get_groq_llm()

# %%
from langchain_core.documents import Document
docs = [
    Document(
        page_content="Peak Performance Gym was founded in 2015 by former Olympic athlete Marcus Chen. With over 15 years of experience in professional athletics, Marcus established the gym to provide personalized fitness solutions for people of all levels. The gym spans 10,000 square feet and features state-of-the-art equipment.",
        metadata={"source": "about.txt"}
    ),
    Document(
        page_content="Peak Performance Gym is open Monday through Friday from 5:00 AM to 11:00 PM. On weekends, our hours are 7:00 AM to 9:00 PM. We remain closed on major national holidays. Members with Premium access can enter using their key cards 24/7, including holidays.",
        metadata={"source": "hours.txt"}
    ),
    Document(
        page_content="Our membership plans include: Basic (₹1,500/month) with access to gym floor and basic equipment; Standard (₹2,500/month) adds group classes and locker facilities; Premium (₹4,000/month) includes 24/7 access, personal training sessions, and spa facilities. We offer student and senior citizen discounts of 15% on all plans. Corporate partnerships are available for companies with 10+ employees joining.",
        metadata={"source": "membership.txt"}
    ),
    Document(
        page_content="Group fitness classes at Peak Performance Gym include Yoga (beginner, intermediate, advanced), HIIT, Zumba, Spin Cycling, CrossFit, and Pilates. Beginner classes are held every Monday and Wednesday at 6:00 PM. Intermediate and advanced classes are scheduled throughout the week. The full schedule is available on our mobile app or at the reception desk.",
        metadata={"source": "classes.txt"}
    ),
    Document(
        page_content="Personal trainers at Peak Performance Gym are all certified professionals with minimum 5 years of experience. Each new member receives a complimentary fitness assessment and one free session with a trainer. Our head trainer, Neha Kapoor, specializes in rehabilitation fitness and sports-specific training. Personal training sessions can be booked individually (₹800/session) or in packages of 10 (₹7,000) or 20 (₹13,000).",
        metadata={"source": "trainers.txt"}
    ),
    Document(
        page_content="Peak Performance Gym's facilities include a cardio zone with 30+ machines, strength training area, functional fitness space, dedicated yoga studio, spin class room, swimming pool (25m), sauna and steam rooms, juice bar, and locker rooms with shower facilities. Our equipment is replaced or upgraded every 3 years to ensure members have access to the latest fitness technology.",
        metadata={"source": "facilities.txt"}
    )
]

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
def get_gemini_embedding_model():
    return GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

# %%
from dotenv import load_dotenv
load_dotenv(override = True)
# Out:
# True

# %%
embedding_function = get_gemini_embedding_model()

# %%
from langchain_community.vectorstores import Chroma
db = Chroma.from_documents(docs,embedding_function)

# %%
retriever = db.as_retriever(search_type="mmr",search_kwargs={"k":3})

# %%
##convert retriever as tool
from langchain_core.tools.retriever import create_retriever_tool
from langchain_core.tools import tool

# %%
retriever_tool = create_retriever_tool(retriever, "retriever_tool",
"Information related to Gym History and Founder, Operating hours about Peak Performance Gym")

@tool
def off_topic():
    """
    Catch all questions not related to Peak Performance gym, history, membership_plan, 
    fitness classes
    """
    return "Forbidden - Do not respond to the user"

# %%
tools = [retriever_tool,off_topic]

# %%
from typing import Annotated, Sequence, Literal, TypedDict
from langchain_core.messages import BaseMessage
from langgraph.graph.message import add_messages

# %%
class AgentState(TypedDict):
    messages: Annotated[Sequence[BaseMessage],add_messages]

# %%
from langchain_core.messages import HumanMessage
from langgraph.prebuilt import ToolNode

# %%
def agent(state):
    messages = state["messages"]
    model = get_groq_llm()
    model = model.bind_tools(tools)
    response = model.invoke(messages)

    return {"messages":[response]}

# %%
def should_continue(state)->Literal["tools",END]:
    messages = state["messages"]
    last_message = messages[-1]
    if last_message.tool_calls:
        return "tools"
    return END

# %%
workflow = StateGraph(AgentState)
workflow.add_node("agent",agent)
tool_node = ToolNode(tools)
workflow.add_node("tools",tool_node)
workflow.add_edge(START,"agent")
workflow.add_conditional_edges("agent",should_continue)
workflow.add_edge("tools","agent")
graph = workflow.compile()

# %%
graph

# %%
result = graph.invoke(
    input = {"messages":[HumanMessage(content="How is the weather")]}
)
result
# Out:
# {'messages': [HumanMessage(content='How is the weather', additional_kwargs={}, response_metadata={}, id='bf9c51d7-b064-41e4-90ec-338d04b1c263'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 172, 'total_tokens': 235, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 44, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': None, 'queue_time': 0.056745167, 'prompt_time': 0.008006593, 'completion_time': 0.133572613, 'total_time': 0.141579206}, 'model_provider': 'openai', 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_a09bde29de', 'id': 'chatcmpl-fd79fc62-1277-4873-abb0-d0a73f8c15f7', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019e312d-acae-75e2-885f-f3d032699c67-0', tool_calls=[{'name': 'off_topic', 'args': {}, 'id': 'fc_128d7432-ca91-44a8-859f-297797d44d9a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 172, 'output_tokens': 63, 'total_tokens': 235, 'input_token_details': {}, 'output_token_details': {'reasoning': 44}}),
#   ToolMessage(content='Forbidden - Do not respond to the user', name='off_topic', id='91b6801c-a811-43c7-ae90-df607f397584', tool_call_id='fc_128d7432-ca91-44a8-859f-297797d44d9a'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 90, 'prompt_tokens': 201, 'total_tokens': 291, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 71, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': None, 'queue_time': 0.054117837, 'prompt_time': 0.009434589, 'completion_time': 0.198365526, 'total_time': 0.207800115}, 'model_provider': 'openai', 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_626f3fc5e0', 'id': 'chatcmpl-302054e2-7416-4efa-82e1-d33dbf8b2251', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019e312d-ae5b-7472-8f86-0d3651b9e64e-0', tool_calls=[{'name': 'off_topic', 'args': {}, 'id': 'fc_9120b7ec-8a13-4ba4-b17c-f638955ef61e', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 201, 'output_tokens': 90, 'total_tokens': 291, 'input_token_details': {}, 'output_token_details': {'reasoning': 71}}),
#   ToolMessage(content='Forbidden - Do not respond to the user', name='off_topic', id='059aef40-4a55-46ab-b3fc-e75f13f1029f', tool_call_id='fc_9120b7ec-8a13-4ba4-b17c-f638955ef61e'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 230, 'total_tokens': 308, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 69, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': None, 'queue_time': 0.051534748, 'prompt_time': 0.009939172, 'completion_time': 0.165564462, 'total_time': 0.175503634}, 'model_provider': 'openai', 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_4a19b1544c', 'id': 'chatcmpl-638e165d-bb93-43f9-bed4-4f7f2a939f54', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e312d-afe2-7a42-935f-b87ea96769f5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 230, 'output_tokens': 78, 'total_tokens': 308, 'input_token_details': {}, 'output_token_details': {'reasoning': 69}})]}

# %%
result = graph.invoke(
    input = {"messages":[HumanMessage(content="Who is the owner and what are the timings of Peak performance gym")]}
)
result
# Out:
# {'messages': [HumanMessage(content='Who is the owner and what are the timings of Peak performance gym', additional_kwargs={}, response_metadata={}, id='70abbc0e-7827-4722-884a-f43f032cb2b0'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 90, 'prompt_tokens': 181, 'total_tokens': 271, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 53, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': None, 'queue_time': 0.054930153, 'prompt_time': 0.049575507, 'completion_time': 0.188640478, 'total_time': 0.238215985}, 'model_provider': 'openai', 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_d29d1d1418', 'id': 'chatcmpl-0f2c9ca0-8cbb-400c-8ca7-c261566a07b6', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019e3133-39b0-77e0-bcec-ec28a742b4bd-0', tool_calls=[{'name': 'retriever_tool', 'args': {'query': 'owner founder and operating hours of Peak Performance Gym'}, 'id': 'fc_b8872d9b-0ddc-43d4-b36f-0a6c98b6dc34', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 181, 'output_tokens': 90, 'total_tokens': 271, 'input_token_details': {}, 'output_token_details': {'reasoning': 53}}),
#   ToolMessage(content='Peak Performance Gym was founded in 2015 by former Olympic athlete Marcus Chen. With over 15 years of experience in professional athletics, Marcus established the gym to provide personalized fitness solutions for people of all levels. The gym spans 10,000 square feet and features state-of-the-art equipment.\n\nPeak Performance Gym is open Monday through Friday from 5:00 AM to 11:00 PM. On weekends, our hours are 7:00 AM to 9:00 PM. We remain closed on major national holidays. Members with Premium access can enter using their key cards 24/7, including holidays.\n\nPersonal trainers at Peak Performance Gym are all certified professionals with minimum 5 years of experience. Each new member receives a complimentary fitness assessment and one free session with a trainer. Our head trainer, Neha Kapoor, specializes in rehabilitation fitness and sports-specific training. Personal training sessions can be booked individually (₹800/session) or in packages of 10 (₹7,000) or 20 (₹13,000).', name='retriever_tool', id='4e6afc02-84b6-4ead-9da0-3617779b4cb9', tool_call_id='fc_b8872d9b-0ddc-43d4-b36f-0a6c98b6dc34'),
#   AIMessage(content='**Owner / Founder**  \n- **Marcus Chen** – a former Olympic athlete who founded Peak Performance Gym in 2015.\n\n**Operating Hours**  \n\n| Day                | Hours                              |\n|--------------------|------------------------------------|\n| Monday – Friday    | 5:00\u202fAM\u202f–\u202f11:00\u202fPM                 |\n| Saturday – Sunday  | 7:00\u202fAM\u202f–\u202f9:00\u202fPM                  |\n| Major national holidays | Closed (except for Premium members) |\n| Premium‑access members | 24\u202f/\u202f7 entry (including holidays) |\n\nSo, the gym is run by Marcus\u202fChen and follows the schedule above for regular members.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 196, 'prompt_tokens': 426, 'total_tokens': 622, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 48, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': None, 'queue_time': 0.053494228, 'prompt_time': 0.022084672, 'completion_time': 0.413021893, 'total_time': 0.435106565}, 'model_provider': 'openai', 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_8db49de948', 'id': 'chatcmpl-80e920d1-f146-465b-9aa4-0fb282de2688', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e3133-3e7e-71f1-bdca-19fb8fb08e4f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 426, 'output_tokens': 196, 'total_tokens': 622, 'input_token_details': {}, 'output_token_details': {'reasoning': 48}})]}

# %%
print(result["messages"][-1].content)
# Out:
# **Owner / Founder**
# - **Marcus Chen** – a former Olympic athlete who founded Peak Performance Gym in 2015.
#
# **Operating Hours**
#
# | Day                | Hours                              |
# |--------------------|------------------------------------|
# | Monday – Friday    | 5:00 AM – 11:00 PM                 |
# | Saturday – Sunday  | 7:00 AM – 9:00 PM                  |
# | Major national holidays | Closed (except for Premium members) |
# | Premium‑access members | 24 / 7 entry (including holidays) |
#
# So, the gym is run by Marcus Chen and follows the schedule above for regular members.
